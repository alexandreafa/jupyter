# %%
def my_func(name=''):
    print('Hello '+name)

# %%
def square(x):
    return x**2

# %%
result = square(4)

# %%
result
# Out:
# 16

# %%
7 ** 4
# Out:
# 2401

# %%
s = "Hi there Sam!"

# %%
list = s.split()

# %%
list
# Out:
# ['Hi', 'there', 'Sam!']

# %%
"Hi there dad!".split()
# Out:
# ['Hi', 'there', 'dad!']

# %%
planet = "Earth"

# %%
diameter = 12742

# %%
planet_string = 'The diameter of {x} is {y} kilometers.'.format(x=planet, y=diameter)

# %%
planet_string
# Out:
# 'The diameter of Earth is 12742 kilometers.'

# %%
lst = [1, 2, [3, 4], [5, [100,200,['hello']],23, 11], 1, 7]

# %%
lst[3][1][2]
# Out:
# ['hello']

# %%
d = {'k1': [1,2,3,{'tricky':['oh','man','inception',{'target':}]}]}
