# %%
import numpy as np

# %%
mylist = [1,2,3]

# %%
type(mylist)
# Out:
# list

# %%
np.array(mylist)
# Out:
# array([1, 2, 3])

# %%
mylist
# Out:
# [1, 2, 3]

# %%
myarr = np.array(mylist)

# %%
type(myarr)
# Out:
# numpy.ndarray

# %%
my_matrix = [[1,2,3], [4,5,6], [7,8,9]]

# %%
my_matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [markdown]
# ### NumPy know that the matrix is 2d

# %%
np.array(my_matrix)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [7, 8, 9]])
